# %%
# !pip install napari
# Out:
# Collecting napari
#   Downloading napari-0.5.4-py3-none-any.whl.metadata (13 kB)
# Collecting appdirs>=1.4.4 (from napari)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl.metadata (9.0 kB)
# Collecting app-model<0.4.0,>=0.3.0 (from napari)
#   Downloading app_model-0.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting cachey>=0.2.1 (from napari)
#   Downloading cachey-0.2.1-py3-none-any.whl.metadata (2.2 kB)
# Requirement already satisfied: certifi>=2018.1.18 in /usr/local/lib/python3.10/dist-packages (from napari) (2024.8.30)
# Requirement already satisfied: dask>=2021.10.0 in /usr/local/lib/python3.10/dist-packages (from dask[array]>=2021.10.0->napari) (2024.10.0)
# Requirement already satisfied: imageio!=2.22.1,>=2.20 in /usr/local/lib/python3.10/dist-packages (from napari) (2.36.0)
# Requirement already satisfied: jsonschema>=3.2.0 in /usr/local/lib/python3.10/dist-packages (from napari) (4.23.0)
# Requirement already satisfied: lazy-loader>=0.2 in /usr/local/lib/python3.10/dist-packages (from napari) (0.4)
# Collecting magicgui>=0.7.0 (from napari)
#   Downloading magicgui-0.9.1-py3-none-any.whl.metadata (7.2 kB)
# Collecting napari-console>=0.0.9 (from napari)
#   Downloading napari_console-0.1.1-py3-none-any.whl.metadata (5.7 kB)
# Collecting napari-plugin-engine>=0.1.9 (from napari)
#   Downloading napari_plugin_engine-0.2.0-py3-none-any.whl.metadata (3.9 kB)
# Collecting napari-svg>=0.1.8 (from napari)
#   Downloading napari_svg-0.2.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting npe2>=0.7.6 (from napari)
#   Downloading npe2-0.7.7-py3-none-any.whl.metadata (3.1 kB)
# Collecting numpydoc>=0.9.2 (from napari)
#   Downloading numpydoc-1.8.0-py3-none-any.whl.metadata (4.3 kB)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from napari) (2.2.2)
# Requirement already satisfied: Pillow>=9.0 in /usr/local/lib/python3.10/dist-packages (from napari) (11.0.0)
# Collecting pint>=0.17 (from napari)
#   Downloading Pint-0.24.4-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: psutil>=5.0 in /usr/local/lib/python3.10/dist-packages (from napari) (5.9.5)
# Collecting psygnal>=0.5.0 (from napari)
#   Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (7.2 kB)
# Requirement already satisfied: pydantic>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from napari) (2.9.2)
# Requirement already satisfied: pygments>=2.6.0 in /usr/local/lib/python3.10/dist-packages (from napari) (2.18.0)
# Requirement already satisfied: PyOpenGL>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from napari) (3.1.7)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.10/dist-packages (from napari) (6.0.2)
# Collecting qtpy>=1.10.0 (from napari)
#   Downloading QtPy-2.4.2-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: scikit-image>=0.19.1 in /usr/local/lib/python3.10/dist-packages (from scikit-image[data]>=0.19.1->napari) (0.24.0)
# Requirement already satisfied: scipy>=1.5.4 in /usr/local/lib/python3.10/dist-packages (from napari) (1.13.1)
# Collecting superqt>=0.6.7 (from napari)
#   Downloading superqt-0.6.7-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: tifffile>=2022.4.8 in /usr/local/lib/python3.10/dist-packages (from napari) (2024.9.20)
# Requirement already satisfied: toolz>=0.10.0 in /usr/local/lib/python3.10/dist-packages (from napari) (0.12.1)
# Requirement already satisfied: tqdm>=4.56.0 in /usr/local/lib/python3.10/dist-packages (from napari) (4.66.6)
# Requirement already satisfied: typing-extensions>=4.2.0 in /usr/local/lib/python3.10/dist-packages (from napari) (4.12.2)
# Collecting vispy<0.15,>=0.14.1 (from napari)
#   Downloading vispy-0.14.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (8.4 kB)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.10/dist-packages (from napari) (1.16.0)
# Requirement already satisfied: numpy>=1.22.2 in /usr/local/lib/python3.10/dist-packages (from napari) (1.26.4)
# Collecting in-n-out>=0.1.5 (from app-model<0.4.0,>=0.3.0->napari)
#   Downloading in_n_out-0.2.1-py3-none-any.whl.metadata (4.1 kB)
# Collecting pydantic-compat>=0.1.1 (from app-model<0.4.0,>=0.3.0->napari)
#   Downloading pydantic_compat-0.1.2-py3-none-any.whl.metadata (8.4 kB)
# Collecting heapdict (from cachey>=0.2.1->napari)
#   Downloading HeapDict-1.0.1-py3-none-any.whl.metadata (1.9 kB)
# Requirement already satisfied: click>=8.1 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari) (8.1.7)
# Requirement already satisfied: cloudpickle>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari) (3.1.0)
# Requirement already satisfied: fsspec>=2021.09.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari) (2024.10.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari) (24.2)
# Requirement already satisfied: partd>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari) (1.4.2)
# Requirement already satisfied: importlib-metadata>=4.13.0 in /usr/local/lib/python3.10/dist-packages (from dask>=2021.10.0->dask[array]>=2021.10.0->napari) (8.5.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.2.0->napari) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.2.0->napari) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.2.0->napari) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=3.2.0->napari) (0.21.0)
# Requirement already satisfied: docstring-parser>=0.7 in /usr/local/lib/python3.10/dist-packages (from magicgui>=0.7.0->napari) (0.16)
# Requirement already satisfied: IPython>=7.7.0 in /usr/local/lib/python3.10/dist-packages (from napari-console>=0.0.9->napari) (7.34.0)
# Requirement already satisfied: ipykernel>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from napari-console>=0.0.9->napari) (5.5.6)
# Collecting qtconsole!=4.7.6,!=5.4.2,>=4.5.1 (from napari-console>=0.0.9->napari)
#   Downloading qtconsole-5.6.1-py3-none-any.whl.metadata (5.0 kB)
# Collecting build>=1 (from npe2>=0.7.6->napari)
#   Downloading build-1.2.2.post1-py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: rich in /usr/local/lib/python3.10/dist-packages (from npe2>=0.7.6->napari) (13.9.4)
# Collecting tomli-w (from npe2>=0.7.6->napari)
#   Downloading tomli_w-1.1.0-py3-none-any.whl.metadata (5.7 kB)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from npe2>=0.7.6->napari) (2.1.0)
# Requirement already satisfied: typer in /usr/local/lib/python3.10/dist-packages (from npe2>=0.7.6->napari) (0.13.0)
# Requirement already satisfied: sphinx>=6 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=0.9.2->napari) (8.1.3)
# Requirement already satisfied: tabulate>=0.8.10 in /usr/local/lib/python3.10/dist-packages (from numpydoc>=0.9.2->napari) (0.9.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->napari) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->napari) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.3.0->napari) (2024.2)
# Requirement already satisfied: platformdirs>=2.1.0 in /usr/local/lib/python3.10/dist-packages (from pint>=0.17->napari) (4.3.6)
# Collecting flexcache>=0.3 (from pint>=0.17->napari)
#   Downloading flexcache-0.3-py3-none-any.whl.metadata (7.0 kB)
# Collecting flexparser>=0.4 (from pint>=0.17->napari)
#   Downloading flexparser-0.4-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->napari) (0.7.0)
# Requirement already satisfied: pydantic-core==2.23.4 in /usr/local/lib/python3.10/dist-packages (from pydantic>=1.9.0->napari) (2.23.4)
# Requirement already satisfied: networkx>=2.8 in /usr/local/lib/python3.10/dist-packages (from scikit-image>=0.19.1->scikit-image[data]>=0.19.1->napari) (3.4.2)
# Requirement already satisfied: pooch>=1.6.0 in /usr/local/lib/python3.10/dist-packages (from scikit-image[data]>=0.19.1->napari) (1.8.2)
# Collecting freetype-py (from vispy<0.15,>=0.14.1->napari)
#   Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (6.3 kB)
# Collecting hsluv (from vispy<0.15,>=0.14.1->napari)
#   Downloading hsluv-5.0.4-py2.py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: kiwisolver in /usr/local/lib/python3.10/dist-packages (from vispy<0.15,>=0.14.1->napari) (1.4.7)
# Collecting pyproject_hooks (from build>=1->npe2>=0.7.6->napari)
#   Downloading pyproject_hooks-1.2.0-py3-none-any.whl.metadata (1.3 kB)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.10/dist-packages (from importlib-metadata>=4.13.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari) (3.21.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari) (0.2.0)
# Requirement already satisfied: traitlets>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari) (5.7.1)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.10/dist-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari) (6.1.12)
# Requirement already satisfied: tornado>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipykernel>=5.2.0->napari-console>=0.0.9->napari) (6.3.3)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (75.1.0)
# Collecting jedi>=0.16 (from IPython>=7.7.0->napari-console>=0.0.9->napari)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (3.0.48)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from IPython>=7.7.0->napari-console>=0.0.9->napari) (4.9.0)
# Requirement already satisfied: locket in /usr/local/lib/python3.10/dist-packages (from partd>=1.4.0->dask>=2021.10.0->dask[array]>=2021.10.0->napari) (1.0.0)
# Requirement already satisfied: requests>=2.19.0 in /usr/local/lib/python3.10/dist-packages (from pooch>=1.6.0->scikit-image[data]>=0.19.1->napari) (2.32.3)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->napari) (1.16.0)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.10/dist-packages (from qtconsole!=4.7.6,!=5.4.2,>=4.5.1->napari-console>=0.0.9->napari) (5.7.2)
# Requirement already satisfied: sphinxcontrib-applehelp>=1.0.7 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.0.0)
# Requirement already satisfied: sphinxcontrib-devhelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.0.0)
# Requirement already satisfied: sphinxcontrib-htmlhelp>=2.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.1.0)
# Requirement already satisfied: sphinxcontrib-jsmath>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (1.0.1)
# Requirement already satisfied: sphinxcontrib-qthelp>=1.0.6 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.0.0)
# Requirement already satisfied: sphinxcontrib-serializinghtml>=1.1.9 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.0.0)
# Requirement already satisfied: Jinja2>=3.1 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (3.1.4)
# Requirement already satisfied: docutils<0.22,>=0.20 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (0.21.2)
# Requirement already satisfied: snowballstemmer>=2.2 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.2.0)
# Requirement already satisfied: babel>=2.13 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (2.16.0)
# Requirement already satisfied: alabaster>=0.7.14 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (1.0.0)
# Requirement already satisfied: imagesize>=1.3 in /usr/local/lib/python3.10/dist-packages (from sphinx>=6->numpydoc>=0.9.2->napari) (1.4.1)
# Collecting pyconify>=0.1.4 (from superqt[iconify]>=0.6.1->magicgui>=0.7.0->napari)
#   Downloading pyconify-0.1.6-py3-none-any.whl.metadata (5.5 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich->npe2>=0.7.6->napari) (3.0.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.10/dist-packages (from typer->npe2>=0.7.6->napari) (1.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->IPython>=7.7.0->napari-console>=0.0.9->napari) (0.8.4)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from Jinja2>=3.1->sphinx>=6->numpydoc>=0.9.2->napari) (3.0.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.10/dist-packages (from jupyter-client->ipykernel>=5.2.0->napari-console>=0.0.9->napari) (24.0.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich->npe2>=0.7.6->napari) (0.1.2)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->IPython>=7.7.0->napari-console>=0.0.9->napari) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython>=7.7.0->napari-console>=0.0.9->napari) (0.2.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari) (3.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.19.0->pooch>=1.6.0->scikit-image[data]>=0.19.1->napari) (2.2.3)
# Downloading napari-0.5.4-py3-none-any.whl (3.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 70.7 MB/s eta 0:00:00
# Downloading app_model-0.3.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.3/64.3 kB 6.6 MB/s eta 0:00:00
# Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Downloading cachey-0.2.1-py3-none-any.whl (6.4 kB)
# Downloading magicgui-0.9.1-py3-none-any.whl (124 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 kB 11.8 MB/s eta 0:00:00
# Downloading napari_console-0.1.1-py3-none-any.whl (10.0 kB)
# Downloading napari_plugin_engine-0.2.0-py3-none-any.whl (33 kB)
# Downloading napari_svg-0.2.0-py3-none-any.whl (15 kB)
# Downloading npe2-0.7.7-py3-none-any.whl (92 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.6/92.6 kB 8.8 MB/s eta 0:00:00
# Downloading numpydoc-1.8.0-py3-none-any.whl (64 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 64.0/64.0 kB 5.7 MB/s eta 0:00:00
# Downloading Pint-0.24.4-py3-none-any.whl (302 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 27.5 MB/s eta 0:00:00
# Downloading psygnal-0.11.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (727 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 727.4/727.4 kB 47.2 MB/s eta 0:00:00
# Downloading QtPy-2.4.2-py3-none-any.whl (95 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 95.2/95.2 kB 9.3 MB/s eta 0:00:00
# Downloading superqt-0.6.7-py3-none-any.whl (90 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 8.7 MB/s eta 0:00:00
# Downloading vispy-0.14.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 71.0 MB/s eta 0:00:00
# Downloading build-1.2.2.post1-py3-none-any.whl (22 kB)
# Downloading flexcache-0.3-py3-none-any.whl (13 kB)
# Downloading flexparser-0.4-py3-none-any.whl (27 kB)
# Downloading in_n_out-0.2.1-py3-none-any.whl (19 kB)
# Downloading pydantic_compat-0.1.2-py3-none-any.whl (13 kB)
# Downloading qtconsole-5.6.1-py3-none-any.whl (125 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 125.0/125.0 kB 12.5 MB/s eta 0:00:00
# Downloading freetype_py-2.5.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 59.5 MB/s eta 0:00:00
# Downloading HeapDict-1.0.1-py3-none-any.whl (3.9 kB)
# Downloading hsluv-5.0.4-py2.py3-none-any.whl (5.3 kB)
# Downloading tomli_w-1.1.0-py3-none-any.whl (6.4 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 65.8 MB/s eta 0:00:00
# Downloading pyconify-0.1.6-py3-none-any.whl (18 kB)
# Downloading pyproject_hooks-1.2.0-py3-none-any.whl (10 kB)
# Installing collected packages: heapdict, appdirs, tomli-w, qtpy, pyproject_hooks, psygnal, napari-plugin-engine, jedi, in-n-out, hsluv, freetype-py, flexparser, flexcache, cachey, vispy, superqt, pyconify, pint, build, pydantic-compat, numpydoc, napari-svg, qtconsole, npe2, magicgui, app-model, napari-console, napari
# Successfully installed app-model-0.3.0 appdirs-1.4.4 build-1.2.2.post1 cachey-0.2.1 flexcache-0.3 flexparser-0.4 freetype-py-2.5.1 heapdict-1.0.1 hsluv-5.0.4 in-n-out-0.2.1 jedi-0.19.2 magicgui-0.9.1 napari-0.5.4 napari-console-0.1.1 napari-plugin-engine-0.2.0 napari-svg-0.2.0 npe2-0.7.7 numpydoc-1.8.0 pint-0.24.4 psygnal-0.11.1 pyconify-0.1.6 pydantic-compat-0.1.2 pyproject_hooks-1.2.0 qtconsole-5.6.1 qtpy-2.4.2 superqt-0.6.7 tomli-w-1.1.0 vispy-0.14.3

# %%
# !pip install imagecodecs
# Out:
# Collecting imagecodecs
#   Downloading imagecodecs-2024.9.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (20 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from imagecodecs) (1.26.4)
# Downloading imagecodecs-2024.9.22-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (43.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 MB 17.4 MB/s eta 0:00:00
# Installing collected packages: imagecodecs
# Successfully installed imagecodecs-2024.9.22

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#to check the pathing of your Google Drive folders and make sure all your stuff is in there
# !ls "/content/drive/MyDrive/Rawfiles/Parameter Tuning/Wiener Alpha/rawdata_Gaussian"
# Out:
# CamB_ch0_er_simulated_raw_Gaussian_px_108nm_0lambda_snr_16.tif
# CamB_ch0_er_simulated_raw_Gaussian_px_108nm_0lambda_snr_32.tif
# CamB_ch0_er_simulated_raw_Gaussian_px_108nm_0lambda_snr_4.tif
# CamB_ch0_er_simulated_raw_Gaussian_px_108nm_0lambda_snr_64.tif
# CamB_ch0_er_simulated_raw_Gaussian_px_108nm_0lambda_snr_8.tif
# CamB_ch0_mito_simulated_raw_Gaussian_px_108nm_0lambda_snr_16.tif
# CamB_ch0_mito_simulated_raw_Gaussian_px_108nm_0lambda_snr_32.tif
# CamB_ch0_mito_simulated_raw_Gaussian_px_108nm_0lambda_snr_4.tif
# CamB_ch0_mito_simulated_raw_Gaussian_px_108nm_0lambda_snr_64.tif
# CamB_ch0_mito_simulated_raw_Gaussian_px_108nm_0lambda_snr_8.tif
# matlab_decon_omw_wienerAlpha0.002
# matlab_decon_omw_wienerAlpha0.012421
# matlab_decon_omw_wienerAlpha0.022842
# matlab_decon_omw_wienerAlpha0.033263
# matlab_decon_omw_wienerAlpha0.043684
# matlab_decon_omw_wienerAlpha0.054105
# matlab_decon_omw_wienerAlpha0.064526
# matlab_decon_omw_wienerAlpha0.074947
# matlab_decon_omw_wienerAlpha0.085368
# matlab_decon_omw_wienerAlpha0.095789
# matlab_decon_omw_wienerAlpha0.10621
# matlab_decon_omw_wienerAlpha0.11663
# matlab_decon_omw_wienerAlpha0.12705
# matlab_decon_omw_wienerAlpha0.13747
# matlab_decon_omw_wienerAlpha0.14789
# matlab_decon_omw_wienerAlpha0.15832
# matlab_decon_omw_wienerAlpha0.16874
# matlab_decon_omw_wienerAlpha0.17916
# matlab_decon_omw_wienerAlpha0.18958
# matlab_decon_omw_wienerAlpha0.2

# %%
my directory looks like my google drive
so
/My Drive/Rawfiles/Parameter Tuning/Wiener Alpha/rawdata_confocal/

put data into specific folders in here as follows:

  |----test_deconv
  -----------contains all my weinerAlpha folders
  |----groundtruth
  -----------contains ground truth files

# %%
import napari
import numpy as np
from pathlib import Path
import tifffile
import re
import pandas as pd
from skimage import metrics
import gc
import psutil
import matplotlib.pyplot as plt
from typing import Dict, List, Tuple

def clear_memory():
    """
    Utility function to clear memory and report usage.
    Critical for handling large microscopy datasets efficiently.
    """
    plt.close('all')  # Close any open matplotlib figures
    gc.collect()      # Force garbage collection
    print(f"Memory usage: {psutil.Process().memory_info().rss / 1024 / 1024:.2f} MB")

class DeconvolutionAnalyzer:
    """
    Analyzes deconvolved microscopy images against ground truth data.
    Handles multiple Wiener parameters and compares quality across z-stacks.
    """
    def __init__(self):
        # Set up file paths
        ##for getting data from our google doc, make sure you change the last item to rawdata_"your modality"
        self.base_path = Path("/content/drive/My Drive/Rawfiles/Parameter Tuning/Wiener Alpha/rawfiles_confocal/")
        self.test_path = self.base_path / "test_deconv"
        self.viewer = None

        # Ground truth reference images
        self.gt_files = {
            'er': self.base_path / 'groundtruth/er_gt_px_108nm.tif',
            'mito': self.base_path / 'groundtruth/mito_gt_px_108nm.tif'
        }

        # Parameters for chunked processing
        self.chunk_size = 10  # Number of z-slices to process at once

        print("Initialization:")
        self._verify_files()

    def _verify_files(self):
        """Check existence of required files and report directory structure."""
        print("\nGround Truth Files:")
        for channel, path in self.gt_files.items():
            print(f"- {channel}: {path.exists()} ({path})")

        wiener_folders = list(self.test_path.glob("*wienerAlpha*"))
        print(f"\nWiener Alpha Folders Found: {len(wiener_folders)}")
        for folder in wiener_folders:
            print(f"- {folder.name}")

    def extract_parameters(self, filename: str, folder_path: str = None) -> dict:
        """
        Extract metadata from filename and folder structure.

        Parameters:
        -----------
        filename : str
            Name of deconvolved image file
        folder_path : str, optional
            Path containing Wiener alpha parameter

        Returns:
        --------
        dict with channel, SNR, and Wiener alpha parameters
        """
        params = {}

        # Extract channel type
        if 'er' in filename.lower():
            params['channel'] = 'er'
        elif 'mito' in filename.lower():
            params['channel'] = 'mito'

        # Extract SNR value
        snr_match = re.search(r'snr_(\d+)', filename)
        if snr_match:
            params['snr'] = int(snr_match.group(1))

        # Extract Wiener alpha from folder name
        if folder_path:
            wiener_match = re.search(r'wienerAlpha([\d.]+)', str(folder_path))
            if wiener_match:
                params['wiener'] = float(wiener_match.group(1))

        return params

    def process_z_stack(self, gt: np.ndarray, deconv: np.ndarray) -> Dict:
        """
        Process and compare a pair of z-stacks.

        Parameters:
        -----------
        gt : np.ndarray
            Ground truth z-stack
        deconv : np.ndarray
            Deconvolved z-stack to compare

        Returns:
        --------
        Dict containing spatial and temporal metrics
        """
        # Match dimensions
        min_z = min(gt.shape[0], deconv.shape[0])
        min_y = min(gt.shape[1], deconv.shape[1])
        min_x = min(gt.shape[2], deconv.shape[2])

        # Crop to matching size
        gt = gt[:min_z, :min_y, :min_x]
        deconv = deconv[:min_z, :min_y, :min_x]

        # Normalize both images to [0,1] range
        gt_norm = (gt - gt.min()) / (gt.max() - gt.min())
        deconv_norm = (deconv - deconv.min()) / (deconv.max() - deconv.min())

        metrics_dict = {
            'mse_values': [],
            'ssim_values': [],
            'z_consistency': []
        }

        # Calculate per-slice metrics
        for z in range(min_z):
            mse = metrics.mean_squared_error(gt_norm[z], deconv_norm[z])
            ssim = metrics.structural_similarity(
                gt_norm[z],
                deconv_norm[z],
                data_range=1.0
            )
            metrics_dict['mse_values'].append(mse)
            metrics_dict['ssim_values'].append(ssim)

        # Calculate temporal consistency between adjacent z-slices
        for z in range(min_z - 1):
            consistency = metrics.structural_similarity(
                deconv_norm[z],
                deconv_norm[z + 1],
                data_range=1.0
            )
            metrics_dict['z_consistency'].append(consistency)

        return metrics_dict

    def analyze_files(self):
        """Main analysis pipeline."""
        try:
            print("\nStarting analysis...")
            clear_memory()

            self.viewer = napari.Viewer()
            results_list = []

            # Process each Wiener alpha folder
            wiener_folders = list(self.test_path.glob("*wienerAlpha*"))

            for folder in wiener_folders:
                print(f"\nProcessing folder: {folder.name}")
                clear_memory()

                # Process each image in the folder
                ##CAN VARY YOUR SNR VALUE HERE
                for test_file in folder.glob("CamB_ch0*_snr_4.tif"):
                    params = self.extract_parameters(test_file.name, folder)
                    channel = params['channel']

                    print(f"\nAnalyzing: {test_file.name}")
                    print(f"Parameters: {params}")

                    # Load and process images
                    gt = tifffile.imread(str(self.gt_files[channel]))
                    deconv = tifffile.imread(str(test_file))

                    # Calculate metrics
                    metrics_dict = self.process_z_stack(gt, deconv)

                    # Store results
                    results_list.append({
                        'channel': channel,
                        'snr': params['snr'],
                        'wiener': params['wiener'],
                        'mse_mean': np.mean(metrics_dict['mse_values']),
                        'mse_std': np.std(metrics_dict['mse_values']),
                        'ssim_mean': np.mean(metrics_dict['ssim_values']),
                        'ssim_std': np.std(metrics_dict['ssim_values']),
                        'z_consistency': np.mean(metrics_dict['z_consistency'])
                    })

                    # Show central z-slice in viewer
                    mid_z = len(metrics_dict['mse_values']) // 2
                    self.viewer.add_image(
                        deconv[mid_z],
                        name=f"{channel}_W{params['wiener']}_SNR{params['snr']}",
                        visible=True
                    )

                    # Clean up large arrays
                    del gt, deconv
                    clear_memory()

            # Create results DataFrame and plot
            self.results = pd.DataFrame(results_list)
            self.plot_comprehensive_results()

            return self.viewer

        except Exception as e:
            print(f"Error in analysis: {e}")
            raise

    def plot_comprehensive_results(self):
        """Generate comprehensive visualization of results."""
        if not hasattr(self, 'results') or self.results.empty:
            return

        fig, axes = plt.subplots(2, 2, figsize=(15, 15))

        # Plot MSE vs Wiener Alpha
        for channel in ['er', 'mito']:
            channel_data = self.results[self.results['channel'] == channel].sort_values('wiener')
            axes[0,0].errorbar(
                channel_data['wiener'],
                channel_data['mse_mean'],
                yerr=channel_data['mse_std'],
                fmt='o-',
                label=channel.upper(),
                capsize=5
            )

        axes[0,0].set_xscale('log')
        axes[0,0].set_xlabel('Wiener Alpha')
        axes[0,0].set_ylabel('Mean Squared Error')
        axes[0,0].set_title('MSE vs Wiener Alpha')
        axes[0,0].grid(True)
        axes[0,0].legend()

        # Plot SSIM vs Wiener Alpha
        for channel in ['er', 'mito']:
            channel_data = self.results[self.results['channel'] == channel].sort_values('wiener')
            axes[0,1].errorbar(
                channel_data['wiener'],
                channel_data['ssim_mean'],
                yerr=channel_data['ssim_std'],
                fmt='o-',
                label=channel.upper(),
                capsize=5
            )

        axes[0,1].set_xscale('log')
        axes[0,1].set_xlabel('Wiener Alpha')
        axes[0,1].set_ylabel('Structural Similarity (SSIM)')
        axes[0,1].set_title('SSIM vs Wiener Alpha')
        axes[0,1].grid(True)
        axes[0,1].legend()

        # Plot Z-consistency
        for channel in ['er', 'mito']:
            channel_data = self.results[self.results['channel'] == channel].sort_values('wiener')
            axes[1,0].plot(
                channel_data['wiener'],
                channel_data['z_consistency'],
                'o-',
                label=channel.upper()
            )

        axes[1,0].set_xscale('log')
        axes[1,0].set_xlabel('Wiener Alpha')
        axes[1,0].set_ylabel('Z-stack Consistency')
        axes[1,0].set_title('Z-stack Consistency vs Wiener Alpha')
        axes[1,0].grid(True)
        axes[1,0].legend()

        # Add best parameters summary
        axes[1,1].axis('off')
        summary_text = "Best Parameters:\n\n"
        for channel in ['er', 'mito']:
            channel_data = self.results[self.results['channel'] == channel]
            best_result = channel_data.loc[channel_data['mse_mean'].idxmin()]
            summary_text += f"{channel.upper()}:\n"
            summary_text += f"Best Wiener: {best_result['wiener']:.6f}\n"
            summary_text += f"MSE: {best_result['mse_mean']:.6f}\n"
            summary_text += f"SSIM: {best_result['ssim_mean']:.6f}\n\n"

        axes[1,1].text(0.1, 0.7, summary_text, fontsize=10, family='monospace')

        plt.tight_layout()
        plt.show()

# Usage
if __name__ == "__main__":
    analyzer = DeconvolutionAnalyzer()
    viewer = analyzer.analyze_files()
# Out:
# Initialization:
#
# Ground Truth Files:
# - er: True (/content/drive/My Drive/Rawfiles/Parameter Tuning/Wiener Alpha/rawfiles_confocal/groundtruth/er_gt_px_108nm.tif)
# - mito: True (/content/drive/My Drive/Rawfiles/Parameter Tuning/Wiener Alpha/rawfiles_confocal/groundtruth/mito_gt_px_108nm.tif)
#
# Wiener Alpha Folders Found: 20
# - matlab_decon_omw_wienerAlpha0.012421
# - matlab_decon_omw_wienerAlpha0.022842
# - matlab_decon_omw_wienerAlpha0.064526
# - matlab_decon_omw_wienerAlpha0.074947
# - matlab_decon_omw_wienerAlpha0.054105
# - matlab_decon_omw_wienerAlpha0.002
# - matlab_decon_omw_wienerAlpha0.033263
# - matlab_decon_omw_wienerAlpha0.043684
# - matlab_decon_omw_wienerAlpha0.085368
# - matlab_decon_omw_wienerAlpha0.15832
# - matlab_decon_omw_wienerAlpha0.18958
# - matlab_decon_omw_wienerAlpha0.11663
# - matlab_decon_omw_wienerAlpha0.095789
# - matlab_decon_omw_wienerAlpha0.10621
# - matlab_decon_omw_wienerAlpha0.14789
# - matlab_decon_omw_wienerAlpha0.16874
# - matlab_decon_omw_wienerAlpha0.12705
# - matlab_decon_omw_wienerAlpha0.13747
# - matlab_decon_omw_wienerAlpha0.17916
# - matlab_decon_omw_wienerAlpha0.2
#
# Starting analysis...
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.012421
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.012421}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.012421}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.022842
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.022842}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.022842}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.064526
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.064526}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.064526}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.074947
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.074947}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.074947}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.054105
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.054105}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.054105}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.002
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.002}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.002}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.033263
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.033263}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.033263}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.043684
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.043684}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.043684}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.085368
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.085368}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.085368}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.15832
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.15832}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.15832}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.18958
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.18958}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.18958}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.11663
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.11663}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.11663}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.095789
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.095789}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.095789}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.10621
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.10621}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.10621}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.14789
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.14789}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.14789}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.16874
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.16874}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.16874}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.12705
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.12705}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.12705}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.13747
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.13747}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.13747}
# Memory usage: 1653.44 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.17916
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.17916}
# Memory usage: 1653.44 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.17916}
# Memory usage: 1653.45 MB
#
# Processing folder: matlab_decon_omw_wienerAlpha0.2
# Memory usage: 1653.45 MB
#
# Analyzing: CamB_ch0_er_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'er', 'snr': 4, 'wiener': 0.2}
# Memory usage: 1653.45 MB
#
# Analyzing: CamB_ch0_mito_simulated_raw_Confocal_1AU_px_108nm_0lambda_snr_4.tif
# Parameters: {'channel': 'mito', 'snr': 4, 'wiener': 0.2}
# Memory usage: 1653.45 MB
